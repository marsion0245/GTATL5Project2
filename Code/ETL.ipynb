# %%
import pandas as pd
import json

# %%
#filter = "JSON file (*.json)|*.json|All Files (*.*)|*.*||"
#filename = reads.OpenFileName("yelp_academic_dataset_business.json", filter)
data_file=pd.read_json(r'C:/Users/Melanie/Documents/GitLab/ETL Project/yelp_academic_dataset_business.json/yelp_academic_dataset_business.json',orient='column',lines=True)

data_file
# Out:
#                                                   address  \
# 0                             2818 E Camino Acequia Drive
# 1                                    30 Eglinton Avenue W
# 2                               10110 Johnston Rd, Ste 15
# 3                           15655 W Roosevelt St, Ste 237
# 4                          4209 Stuart Andrew Blvd, Ste F
# 5       Credit Valley Town Plaza, F2 - 6045 Creditview Rd
# 6                        20 Douglas Woods Drive Southeast
# 7                    4545 E Tropicana Rd Ste 8, Tropicana
# 8                                   5940 W Union Hills Dr
# 9                                         21689 Lorain Rd
# 10                           1210 8th Street SW, Unit 220
# 11                                2450 E Indian School Rd
# 12                               119 Landings Dr, Ste 101
# 13                                        5981 Andrews Rd
# 14                                           4145 Erie St
# ...

# %%
#var wantedData = data_file.filter(data_file.categoreis = ;
#filtered_data=filter(lambda k: 'Restaurants' in k, data_file)
data_file=data_file.dropna(how='any')
total_restaurants=data_file[data_file['categories'].str.contains("Restaurants")]
Korean_restaurant=data_file[data_file['categories'].str.contains("Korean")]
Italian_restaurant=data_file[data_file['categories'].str.contains("Italian")]
Mexican_restaurant=data_file[data_file['categories'].str.contains("Mexican")]

# %%
Mexican_restaurant
# Out:
#                                    address  \
# 11                 2450 E Indian School Rd
# 25                   6055 E Lake Mead Blvd
# 96                     1614 Queen Street E
# 156          1770 W Horizon Ridge, Ste 100
# 181       3415 West Glendale Ave, Bldg 25A
# 285                     971 O'Connor Drive
# 343                    10624 S Eastern Ave
# 485                  705 N 1st St, Ste 110
# 542                  3475 Las Vegas Blvd S
# 673                     1923 E Mcdowell Rd
# 679                    162 Danforth Avenue
# 708                    3209 E Camelback Rd
# 779                     2101 Texas Star Ln
# 790                9800 State Rt 14, Ste E
# 821                156 Rue Prince Arthur E
# 832                   777 W Lake Mead Pkwy
# 841                  4461 Rue Saint -Denis
# 861                         930 Nevada Hwy
# 1009                       2004 Crocker Rd
# 1448                    119 E Southern Ave
# 1469                     552 N Eastern Ave
# ...

# %%
data_file.describe()
# Out:
#              is_open       latitude      longitude   review_count  \
# count  129268.000000  129268.000000  129268.000000  129268.000000
# mean        0.843565      38.348179     -97.976657      44.508370
# std         0.363268       4.867658      16.625511     131.780404
# min         0.000000      33.204642    -115.477519       3.000000
# 25%         1.000000      33.625583    -112.272915       6.000000
# 50%         1.000000      36.127674    -111.790583      13.000000
# 75%         1.000000      43.112978     -80.037140      36.000000
# max         1.000000      51.296592     -72.945050    8348.000000
#
#                stars
# count  129268.000000
# mean        3.712644
# std         0.934989
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.500000
# max         5.000000

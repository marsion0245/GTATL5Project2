# %%
# import dependancies
import pandas as pd
import json
import os

# Import SQL Alchemy
from sqlalchemy import create_engine

# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.ext.automap import automap_base
Base = declarative_base()

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float, Boolean, DateTime, Date, func
from sqlalchemy.orm import relationship

from datetime import datetime

DATASOURCE = 1 v # Default data source

# Hide warning messages in notebook
#import warnings
#warnings.filterwarnings('ignore')

# %%
# Create classes
class RestaurantCls(Base):
    __tablename__ = 'Restaurant'
    Id = Column(Integer, primary_key=True)
    Name = Column(String(255))
    BusinessId = Column(String(255))
    # location
    StateId = Column(Integer) 
    City = Column(String(100))
    Street = Column(String(250))
    ZipCode = Column(String(10))
    # Operational info
    PriceRange = Column(Integer)
    Rating = Column(Float)
    IsClosed = Column(Boolean)
    SourceId = Column(Integer)
    Date = Column(Date, onupdate=datetime.now())

class CategoryCls(Base):
    __tablename__ = 'Category'
    Id = Column(Integer, primary_key=True)
    Alias = Column(String(255))
    Title = Column(String(255))
    SourceId = Column(Integer)
    Date = Column(Date, default=func.now())

# %%
# read data from files created by calling Yelp API
#data_file=pd.read_json("data.txt", lines=False)
#data_file
#data = json.load(open('data.txt'))
#df = pd.DataFrame(data["businesses"])
#df

# %%
#data = json.load(open('YelpData.txt'))
#df = pd.DataFrame(data["businesses"])
#df

# %%
def read_rest_data(file):

    with open(file, "r") as read_file:
        restaurants = json.load(read_file)["businesses"]

    # Hash of categories
    categories = {}

    # List of restaurants
    rest_list = []

    # List of restaurant categories
    rest_cat = []
    
    for restaurant in restaurants:
        id = restaurant["id"]
        name = restaurant["name"]

        # location
        location = restaurant["location"]
        # All address entries into street
        street = location["address1"]
        street2 = location["address2"]
        street3 = location["address3"]
        if(street2 and not street2.isspace()):
            street += " " + street2 
        if(street3 and not street3.isspace()):
            street += " " + street3 

        # operational info
        for c in restaurant["categories"]:
            # Object to list of categories 
            rest_cat.append((id, CategoryCls(Alias = c['alias'], Title = c['title'] )))
            categories[c['alias']] = c['title']

        if(restaurant.get("price")):
            price = restaurant["price"].count('$') 
        else:
            price = None # some entries miss price

        restaurantObj = RestaurantCls(
            Name = restaurant["name"],
            BusinessId = restaurant["id"],
            City = location["city"],
            Street = street,
            ZipCode = location["zip_code"],
            PriceRange = price,
            Rating = float(restaurant["rating"]),
            IsClosed = bool(restaurant["is_closed"])
        )
        rest_list.append(restaurantObj)
    
    print(len(rest_list))
    return rest_list, rest_cat, categories

# %% [markdown]
# ### Load data from file into objects for further processing
# * Use direct data reader, not Pandas df to get values

# %% [markdown]
# ### Load data from file into objects for further processing

# %%
fn = os.path.join("..", "Data", "YelpData.txt")
restaurants, restaurant_categories, categories = read_rest_data(fn)
# Out:
# 50

# %%
# Load categories into database
import psycopg2
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/ETLproject')

# Reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

Base.classes.keys()
# Out:
# ['State',
#  'Category',
#  'Restaturant',
#  'RestaurantCategory',
#  'StatePCE',
#  'StatePopulation']

# %%
from sqlalchemy.orm import Session
session = Session(engine)

# Note that adding to the session does not update the table. It queues up those queries.
#session.add(Pet(name='Justin Timbersnake', type='snek', age=2))
for alias, title in categories.items():
    print(f"{alias} - {title}")
    categoryObj = CategoryCls(Id=None, Alias = alias, Title = title)
    session.add(categoryObj)

# commit() flushes whatever remaining changes remain to the database, and commits the transaction.
session.commit()
# Out:
# icecream - Ice Cream & Frozen Yogurt
# bakeries - Bakeries
# french - French
# soulfood - Soul Food
# breakfast_brunch - Breakfast & Brunch
# newamerican - American (New)
# wine_bars - Wine Bars
# cafes - Cafes
# desserts - Desserts
# seafood - Seafood
# seafoodmarkets - Seafood Markets
# raw_food - Live/Raw Food
# customcakes - Custom Cakes
# tradamerican - American (Traditional)
# steak - Steakhouses
# burmese - Burmese
# asianfusion - Asian Fusion
# greek - Greek
# mediterranean - Mediterranean
# chinese - Chinese
# chicken_wings - Chicken Wings
# noodles - Noodles
# modern_european - Modern European
# cakeshop - Patisserie/Cake Shop
# macarons - Macarons
# mexican - Mexican
# bars - Bars
# vietnamese - Vietnamese
# sandwiches - Sandwiches
# pizza - Pizza
# italian - Italian
# cocktailbars - Cocktail Bars
# ramen - Ramen
# british - British
# fishnchips - Fish & Chips
# donuts - Donuts
# landmarks - Landmarks & Historical Buildings
# parks - Parks
# tapasmallplates - Tapas/Small Plates
# latin - Latin American
# brazilian - Brazilian
# playgrounds - Playgrounds
# basketballcourts - Basketball Courts
# german - German
# coffee - Coffee & Tea
# museums - Museums
# korean - Korean
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     549     def do_execute(self, cursor, statement, parameters, context=None):
# --> 550         cursor.execute(statement, parameters)
#     551
#
# UniqueViolation: duplicate key value violates unique constraint "Category_UIDX1"
# DETAIL:  Key ("Alias")=(icecream) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-30-f1c8ed42c821> in <module>
#      10
#      11 # commit() flushes whatever remaining changes remain to the database, and commits the transaction.
# ---> 12 session.commit()
#      13
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py in commit(self)
#    1025                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#    1026
# -> 1027         self.transaction.commit()
#    1028
#    1029     def prepare(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py in commit(self)
#     492         self._assert_active(prepared_ok=True)
#     493         if self._state is not PREPARED:
# --> 494             self._prepare_impl()
#     495
#     496         if self._parent is None or self.nested:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py in _prepare_impl(self)
#     471                 if self.session._is_clean():
#     472                     break
# --> 473                 self.session.flush()
#     474             else:
#     475                 raise exc.FlushError(
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py in flush(self, objects)
#    2457         try:
#    2458             self._flushing = True
# -> 2459             self._flush(objects)
#    2460         finally:
#    2461             self._flushing = False
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py in _flush(self, objects)
#    2595         except:
#    2596             with util.safe_reraise():
# -> 2597                 transaction.rollback(_capture_exception=True)
#    2598
#    2599     def bulk_save_objects(
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152         if value.__traceback__ is not tb:
#     153             raise value.with_traceback(tb)
# --> 154         raise value
#     155
#     156     def u(s):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py in _flush(self, objects)
#    2555             self._warn_on_events = True
#    2556             try:
# -> 2557                 flush_context.execute()
#    2558             finally:
#    2559                 self._warn_on_events = False
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\unitofwork.py in execute(self)
#     420         else:
#     421             for rec in topological.sort(self.dependencies, postsort_actions):
# --> 422                 rec.execute(self)
#     423
#     424     def finalize_flush_changes(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\unitofwork.py in execute(self, uow)
#     587             self.mapper,
#     588             uow.states_for_mapper_hierarchy(self.mapper, False, False),
# --> 589             uow,
#     590         )
#     591
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\persistence.py in save_obj(base_mapper, states, uowtransaction, single)
#     243             mapper,
#     244             table,
# --> 245             insert,
#     246         )
#     247
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\orm\persistence.py in _emit_insert_statements(base_mapper, uowtransaction, cached_connections, mapper, table, insert, bookkeeping)
#    1136                 else:
#    1137                     result = cached_connections[connection].execute(
# -> 1138                         statement, params
#    1139                     )
#    1140
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     397     exc_type, exc_value, exc_tb = exc_info
#     398     cause = exc_value if exc_value is not exception else None
# --> 399     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     400
#     401
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151             value.__cause__ = cause
#     152         if value.__traceback__ is not tb:
# --> 153             raise value.with_traceback(tb)
#     154         raise value
#     155
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1242                 if not evt_handled:
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#    1246         except BaseException as e:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     548
#     549     def do_execute(self, cursor, statement, parameters, context=None):
# --> 550         cursor.execute(statement, parameters)
#     551
#     552     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "Category_UIDX1"
# DETAIL:  Key ("Alias")=(icecream) already exists.
#
# [SQL: INSERT INTO "Category" ("Alias", "Title") VALUES (%(Alias)s, %(Title)s) RETURNING "Category"."Id"]
# [parameters: {'Alias': 'icecream', 'Title': 'Ice Cream & Frozen Yogurt'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
# Load restaurants into database
for r in restaurants:
    print(r.Name)
# Out:
# Bi-Rite Creamery
# Brenda's French Soul Food
# Gary Danko
# Tartine Bakery & Cafe
# Hog Island Oyster Co
# Mitchell's Ice Cream
# House of Prime Rib
# Burma Superstar
# The House
# Kokkari Estiatorio
# San Tung
# Nopa
# B Patisserie
# El Farolito
# Fog Harbor Fish House
# Zazie
# Saigon Sandwich
# Golden Boy Pizza
# Sweet Maple
# Liholiho Yacht Club
# Tony's Pizza Napoletana
# Sotto Mare Oysteria & Seafood
# Foreign Cinema
# Golden Gate Bakery
# Little Star Pizza
# Marufuku Ramen SF
# Mama's On Washington Square
# Chapeau!
# Humphry Slocombe Ice Cream
# The Codmother Fish & Chips
# La Taqueria
# Bob's Donut & Pastry Shop
# Golden Gate Bridge
# Twin Peaks
# State Bird Provisions
# Arizmendi Bakery
# Espetus Brazilian Steak House
# Mission Dolores Park
# Dottie's True Blue Cafe
# Kitchen Story
# Suppenküche
# Beretta
# Philz Coffee
# Schubert's Bakery
# Alcatraz Island
# Golden Gate Park
# HRD
# Anthony's Cookies
# Arsicault Bakery
# Swan Oyster Depot

# %%
# load resturant categories into database
for r in restaurant_categories:
    print(f"{r[0]}; {r[1].alias}; {r[1].title}")
# Out:
# wGl_DyNxSv8KUtYgiuLhmA; icecream; Ice Cream & Frozen Yogurt
# wGl_DyNxSv8KUtYgiuLhmA; bakeries; Bakeries
# lJAGnYzku5zSaLnQ_T6_GQ; french; French
# lJAGnYzku5zSaLnQ_T6_GQ; soulfood; Soul Food
# lJAGnYzku5zSaLnQ_T6_GQ; breakfast_brunch; Breakfast & Brunch
# WavvLdfdP6g8aZTtbBQHTw; newamerican; American (New)
# WavvLdfdP6g8aZTtbBQHTw; french; French
# WavvLdfdP6g8aZTtbBQHTw; wine_bars; Wine Bars
# ri7UUYmx21AgSpRsf4-9QA; bakeries; Bakeries
# ri7UUYmx21AgSpRsf4-9QA; cafes; Cafes
# ri7UUYmx21AgSpRsf4-9QA; desserts; Desserts
# Xg-FyjVKAN70LO4u4Z1ozg; seafood; Seafood
# Xg-FyjVKAN70LO4u4Z1ozg; seafoodmarkets; Seafood Markets
# Xg-FyjVKAN70LO4u4Z1ozg; raw_food; Live/Raw Food
# 76smcUUGRvq3k1MVPUXbnA; icecream; Ice Cream & Frozen Yogurt
# 76smcUUGRvq3k1MVPUXbnA; customcakes; Custom Cakes
# oT08T3Vpn1I7jDmrBBRMTw; tradamerican; American (Traditional)
# oT08T3Vpn1I7jDmrBBRMTw; steak; Steakhouses
# oT08T3Vpn1I7jDmrBBRMTw; wine_bars; Wine Bars
# eYXwVR4mMAjzkJnm5wneHQ; burmese; Burmese
# ZoZjbOYR-apY8XvommlNUA; asianfusion; Asian Fusion
# PsY5DMHxa5iNX_nX0T-qPA; greek; Greek
# PsY5DMHxa5iNX_nX0T-qPA; mediterranean; Mediterranean
# M0JTO3oyu6gxh1mfFjU-dA; chinese; Chinese
# M0JTO3oyu6gxh1mfFjU-dA; chicken_wings; Chicken Wings
# M0JTO3oyu6gxh1mfFjU-dA; noodles; Noodles
# ttarnopezxmp2ROB1N2PaA; newamerican; American (New)
# ttarnopezxmp2ROB1N2PaA; modern_european; Modern European
# ttarnopezxmp2ROB1N2PaA; desserts; Desserts
# 2XQm-uFcTS7oc8MFP-8olA; bakeries; Bakeries
# 2XQm-uFcTS7oc8MFP-8olA; cakeshop; Patisserie/Cake Shop
# 2XQm-uFcTS7oc8MFP-8olA; macarons; Macarons
# SGRmnarrNuVEsAjYdEoA0w; mexican; Mexican
# f-m7-hyFzkf0HSEeQ2s-9A; seafood; Seafood
# f-m7-hyFzkf0HSEeQ2s-9A; bars; Bars
# gqVl3RprESEqkIPeJH0yOg; breakfast_brunch; Breakfast & Brunch
# gqVl3RprESEqkIPeJH0yOg; french; French
# hqQoVK0vadOX7_4gN1sh3g; vietnamese; Vietnamese
# hqQoVK0vadOX7_4gN1sh3g; sandwiches; Sandwiches
# PTFxtXS47ZVRCdZIrEWvGw; pizza; Pizza
# PTFxtXS47ZVRCdZIrEWvGw; italian; Italian
# -DrR38H1Abk0wCyu9XOLug; tradamerican; American (Traditional)
# -DrR38H1Abk0wCyu9XOLug; breakfast_brunch; Breakfast & Brunch
# -DrR38H1Abk0wCyu9XOLug; sandwiches; Sandwiches
# KkAVX3Wb7E3lP5F_f_8pXg; bars; Bars
# KkAVX3Wb7E3lP5F_f_8pXg; newamerican; American (New)
# KkAVX3Wb7E3lP5F_f_8pXg; seafood; Seafood
# mSMZJj2pFvttWLpcDmgrEA; pizza; Pizza
# mSMZJj2pFvttWLpcDmgrEA; italian; Italian
# mSMZJj2pFvttWLpcDmgrEA; cocktailbars; Cocktail Bars
# 8dUaybEPHsZMgr1iKgqgMQ; seafood; Seafood
# 8dUaybEPHsZMgr1iKgqgMQ; italian; Italian
# 8dUaybEPHsZMgr1iKgqgMQ; bars; Bars
# n6L5VIGunR51-D55C-eYeQ; breakfast_brunch; Breakfast & Brunch
# n6L5VIGunR51-D55C-eYeQ; mediterranean; Mediterranean
# n6L5VIGunR51-D55C-eYeQ; cocktailbars; Cocktail Bars
# m3xdxV8YNH5uh1N01xdnLA; bakeries; Bakeries
# __I9HmtBMV4dDkEgT22V4g; pizza; Pizza
# __I9HmtBMV4dDkEgT22V4g; italian; Italian
# __I9HmtBMV4dDkEgT22V4g; bars; Bars
# HHtpR0RslupSQ99GIIwW5A; ramen; Ramen
# MvAo0hj9FXOeNL5PwBZ0fQ; breakfast_brunch; Breakfast & Brunch
# L5vSeC_sa3TUQW_lticqyA; french; French
# L5vSeC_sa3TUQW_lticqyA; wine_bars; Wine Bars
# 47OC_X6KkiDDQ4jwoCUjFg; icecream; Ice Cream & Frozen Yogurt
# PDhfVvcVXgBinZf5I6s1KQ; british; British
# PDhfVvcVXgBinZf5I6s1KQ; fishnchips; Fish & Chips
# PDhfVvcVXgBinZf5I6s1KQ; seafood; Seafood
# JARsJVKLPgs_yC3cwDnp7g; mexican; Mexican
# GXu3PD4IPsxIHpo011aydg; bakeries; Bakeries
# GXu3PD4IPsxIHpo011aydg; donuts; Donuts
# Lz7ydUVmsr2DekT9enEhvw; landmarks; Landmarks & Historical Buildings
# WV2fVK6OJfzn2BkRGpbP7A; parks; Parks
# WV2fVK6OJfzn2BkRGpbP7A; landmarks; Landmarks & Historical Buildings
# QZQGRJZ4bZCmNoXjs3z1XQ; tapasmallplates; Tapas/Small Plates
# QZQGRJZ4bZCmNoXjs3z1XQ; newamerican; American (New)
# QZQGRJZ4bZCmNoXjs3z1XQ; desserts; Desserts
# xDwEMq8kgT0eQepn90Jkvg; bakeries; Bakeries
# xDwEMq8kgT0eQepn90Jkvg; pizza; Pizza
# ciEDsTWhajcdL3KuJqBRlw; steak; Steakhouses
# ciEDsTWhajcdL3KuJqBRlw; latin; Latin American
# ciEDsTWhajcdL3KuJqBRlw; brazilian; Brazilian
# Tf_27JvnneEx0Tz79UwShg; parks; Parks
# Tf_27JvnneEx0Tz79UwShg; playgrounds; Playgrounds
# Tf_27JvnneEx0Tz79UwShg; basketballcourts; Basketball Courts
# uEeWn6sPq-giWvfE9uhQ7A; tradamerican; American (Traditional)
# uEeWn6sPq-giWvfE9uhQ7A; breakfast_brunch; Breakfast & Brunch
# uEeWn6sPq-giWvfE9uhQ7A; cafes; Cafes
# XQLmEdXoMzOpffwoFaBtaQ; breakfast_brunch; Breakfast & Brunch
# XQLmEdXoMzOpffwoFaBtaQ; asianfusion; Asian Fusion
# XQLmEdXoMzOpffwoFaBtaQ; newamerican; American (New)
# DGyoVB9PdI9_jw0CNi_OPg; german; German
# 4KfQnlcSu4bbTqnvGdGptw; italian; Italian
# 4KfQnlcSu4bbTqnvGdGptw; pizza; Pizza
# 4KfQnlcSu4bbTqnvGdGptw; breakfast_brunch; Breakfast & Brunch
# akXf1BdFZjQb2fO8Ca7FtA; coffee; Coffee & Tea
# DyXoC_NhJW0Xx5j_OPQRHQ; bakeries; Bakeries
# DyXoC_NhJW0Xx5j_OPQRHQ; desserts; Desserts
# Y12NJdzfE-33OQtoHmomMw; museums; Museums
# Y12NJdzfE-33OQtoHmomMw; landmarks; Landmarks & Historical Buildings
# KIVq5BlJKTipwtB3NATX0g; parks; Parks
# bUr4iq2mKKiBOu2HKynylg; korean; Korean
# bUr4iq2mKKiBOu2HKynylg; asianfusion; Asian Fusion
# bUr4iq2mKKiBOu2HKynylg; mexican; Mexican
# PrlH7YcQ22m9DyuWbxJjMA; bakeries; Bakeries
# PrlH7YcQ22m9DyuWbxJjMA; coffee; Coffee & Tea
# 1U9_ZNruMLf4EL0pMoxb_w; bakeries; Bakeries
# eI0DpD2Xx8hFlk7eAdFCqQ; seafood; Seafood
